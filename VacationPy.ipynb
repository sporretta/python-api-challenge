# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("WeatherPy/cities.csv")

# Display sample data
city_data_df.head(20)
# Out:
#     City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0         0             west island -12.1568   96.8225    298.14        78
# 1         1                canutama  -6.5339  -64.3831    309.41        23
# 2         2           atafu village  -8.5421 -172.5159    302.13        70
# 3         3  hawaiian paradise park  19.5933 -154.9731    299.88        88
# 4         4          puerto natales -51.7236  -72.4875    269.94        76
# 5         5               grytviken -54.2811  -36.5092    267.17        76
# 6         6               jamestown  42.0970  -79.2353    301.22        58
# 7         7                  xinzhi  36.4989  111.7047    300.25        50
# 8         8                   lihue  21.9789 -159.3672    298.96        81
# 9         9                  albany  42.6001  -73.9662    299.61        64
# 10       10                  sabang   5.8933   95.3214    301.56        74
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_data_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    color = "City",
    hover_cols = [ "Country"]
)
# Display the map
city_data_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
#First convert temperture to celcius
city_data_df['Max Temp'] -=273.15

# %%
# Narrow down cities that fit criteria and drop any results with null values

#narrow the dataframe to ideal weather

#max temperature less than 31 C but greater than 15 C
#humidity less than 75%
#cloudiness less than 25
ideal_weather_df= city_data_df.loc[ (city_data_df['Max Temp'] > 15) & (city_data_df['Max Temp'] < 31) & (city_data_df['Humidity'] < 75) & (city_data_df['Cloudiness'] < 25)]
#city_data_df.drop(not_ideal_weather , inplace=True)

# Drop any rows with null values
ideal_weather_df=ideal_weather_df.dropna()

# Display sample data
ideal_weather_df.head(20)
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 2          2     atafu village  -8.5421 -172.5159     28.98        70
# 6          6         jamestown  42.0970  -79.2353     28.07        58
# 7          7            xinzhi  36.4989  111.7047     27.10        50
# 13        13              hami  42.8000   93.4500     27.84        22
# 15        15          thompson  55.7435  -97.8558     25.09        38
# 22        22             pisco -13.7000  -76.2167     22.03        64
# 24        24  minas de marcona -15.2119  -75.1103     17.90        57
# 39        39             conde  -7.2597  -34.9075     26.70        74
# 43        43            tukrah  32.5341   20.5791     29.41        67
# 59        59            kukawa  12.9234   13.5606     30.84        51
# 63        63          misratah  32.3754   15.0925     30.98        58
# 65        65            bethel  41.3712  -73.4140     30.38        54
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df=ideal_weather_df[['City','Country',"Lat",'Lng','Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API

hotel_df['Hotel Name']=''
# Display sample data
hotel_df.head()
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 2   atafu village      TK  -8.5421 -172.5159        70
# 6       jamestown      US  42.0970  -79.2353        58
# 7          xinzhi      CN  36.4989  111.7047        50
# 13           hami      CN  42.8000   93.4500        22
# 15       thompson      CA  55.7435  -97.8558        38

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    'categories': 'accommodation.hotel',
    'limit':20,
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude=row['Lat']
    longitude=row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
   # print(name_address.url)
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# atafu village - nearest hotel: No hotel found
# jamestown - nearest hotel: DoubleTree Jamestown
# xinzhi - nearest hotel: No hotel found
# hami - nearest hotel: Хами
# thompson - nearest hotel: Thompson Inn
# pisco - nearest hotel: La Portada
# minas de marcona - nearest hotel: No hotel found
# conde - nearest hotel: Paladino
# tukrah - nearest hotel: No hotel found
# kukawa - nearest hotel: No hotel found
# misratah - nearest hotel: الفندق السياحى
# bethel - nearest hotel: Hampton Inn Danbury
# tupiza - nearest hotel: Aramayo Hostal
# la libertad - nearest hotel: Hotel Mar Caribe
# urumqi - nearest hotel: 百时快捷酒店红山店
# howard springs - nearest hotel: No hotel found
# hovd - nearest hotel: Khovd hotel
# shakhtersk - nearest hotel: No hotel found
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# sault ste. marie - nearest hotel: Holiday Inn
# la malbaie - nearest hotel: Auberge sur la Côte
# odessa - nearest hotel: Готель Венера
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)
# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
